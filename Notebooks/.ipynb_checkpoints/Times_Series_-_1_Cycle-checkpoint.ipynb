# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numpy.polynomial.polynomial import polyfit
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from numpy import cov
import xarray as xr
import scipy.stats as stats
import math
from scipy.stats import linregress
import numpy.polynomial.polynomial as poly
from sklearn.linear_model import LinearRegression
import scipy.interpolate as interpolate
from scipy.optimize import curve_fit
import cartopy.io.img_tiles as cimgt
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.shapereader as shpreader
import cartopy.io.img_tiles as cimgt
import cartopy.mpl.geoaxes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from cartopy import config
from matplotlib.transforms import offset_copy
# %matplotlib inline
import cmocean
import glob
from scipy.io import netcdf_file as netcdf
from cartopy.feature import ShapelyFeature
from cartopy.io.shapereader import Reader
from shapely import geometry
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from scipy import integrate
import scipy as sci
import cartopy.io.shapereader as shpreader
from cartopy.feature import ShapelyFeature
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from mpl_toolkits.mplot3d.axes3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
from scipy.stats import kde
from scipy import signal
import metpy.calc as mpc
import matplotlib.pylab as pl
from metpy.units import units
import pymannkendall as mk

# %%
plt.rcParams.update({'font.size': 7})
plt.rcParams['font.family'] = 'Arial'
mpl.rcParams['figure.dpi'] = 300
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
ymax = 4.2
tmax = 6
# parameters from simulations
omega = 1.41e-4 #tidal frequency
T = 2*np.pi/omega 
nu = 2.0e-6 #molecular viscosity (m^2 s^-1)
Pr = 14 #Prandtl number (dimensionles)
L = 3.35e5 # Latent heat of melting (units)
cp = 4.184e3 # Heat capacity of the ocean (units)
sy = 365*24*3600
rho0 = 1030 #kg/m^{-3}
Sc = 1500
Rc = 0.2
Xi = 0.052
alpha = 3.8e-5
beta = 7.8e-4
corio = 1.37e-4
gravity = 9.8
vonk = 0.41
kT = 1.4e-7 #m^2/s Thermal Diffusivity
kS = 1.3e-9 #m^2/s Salt Diffusivity

# %%
se_df = xr.open_dataset('C:/Users/bajus/Downloads/tidal_melting/tidal_melting/data/stokes-ekman/ISOBL_model_output.nc')
se_ds = xr.open_dataset('C:/Users/bajus/Downloads/tidal_melting/tidal_melting/data/stokes-ekman/mean_prof_stat.nc')

s_df = xr.open_dataset('C:/Users/bajus/Downloads/tidal_melting/tidal_melting/data/stokes/ISOBL_model_output.nc')
s_ds = xr.open_dataset('C:/Users/bajus/Downloads/tidal_melting/tidal_melting/data/stokes/mean_prof_stat.nc')

# %%
# %store -r se_L_plus_025
# %store -r se_L_plus_05
# %store -r se_L_plus_15
# %store -r se_L_plus_0

# %store -r s_L_plus_025
# %store -r s_L_plus_05
# %store -r s_L_plus_15
# %store -r s_L_plus_0


# %store -r se_sal_trans_coeff_025_1
# %store -r se_sal_trans_coeff_05_1
# %store -r se_sal_trans_coeff_15_1
# %store -r se_sal_trans_coeff_0

# %store -r se_sal_trans_coeff_025_2
# %store -r se_sal_trans_coeff_05_2
# %store -r se_sal_trans_coeff_15_2
# %store -r se_sal_trans_coeff_0_2

# %store -r s_sal_trans_coeff_025_1
# %store -r s_sal_trans_coeff_05_1
# %store -r s_sal_trans_coeff_15_1
# %store -r s_sal_trans_coeff_0

# %store -r s_sal_trans_coeff_025_2
# %store -r s_sal_trans_coeff_05_2
# %store -r s_sal_trans_coeff_15_2
# %store -r s_sal_trans_coeff_0_2


# %store -r se_heat_trans_coeff_025_1
# %store -r se_heat_trans_coeff_05_1
# %store -r se_heat_trans_coeff_15_1
# %store -r se_heat_trans_coeff_0

# %store -r se_heat_trans_coeff_025_2
# %store -r se_heat_trans_coeff_05_2
# %store -r se_heat_trans_coeff_15_2
# %store -r se_heat_trans_coeff_0_2

# %store -r s_heat_trans_coeff_025_1
# %store -r s_heat_trans_coeff_05_1
# %store -r s_heat_trans_coeff_15_1
# %store -r s_heat_trans_coeff_0

# %store -r s_heat_trans_coeff_025_2
# %store -r s_heat_trans_coeff_05_2
# %store -r s_heat_trans_coeff_15_2
# %store -r s_heat_trans_coeff_0_2


# %store -r se_u_star_3
# %store -r se_ustar

# %store -r s_u_star_3
# %store -r s_ustar

# %%
def cycle_average_1d(var, time, omega, start_cycle, end_cycle, dt):
    import numpy as np
    
    T = 2*np.pi/omega
    NT = int(np.floor(T/dt))
    #print(NT)
    t_cycle = np.linspace(0, T, NT)
    
    if np.floor(time[-2]/T)<end_cycle:
        print('record not', end_cycle, ' cycles long!!')
        return
    
    var_cycle = np.zeros(len(t_cycle))
    
    for ii in range(start_cycle,end_cycle):
        ttmp = time - ii*T
        tmp = np.interp(t_cycle, ttmp, var)
        var_cycle = var_cycle+tmp
        
    var_cycle = var_cycle/(end_cycle-start_cycle)
    return t_cycle, var_cycle

# %%
se_L_plus_025_1cyc = cycle_average_1d(se_L_plus_025, se_df['t'], omega, 3, 6, 100)
se_L_plus_05_1cyc = cycle_average_1d(se_L_plus_05, se_df['t'], omega, 3, 6, 100)
se_L_plus_15_1cyc = cycle_average_1d(se_L_plus_15, se_df['t'], omega, 3, 6, 100)
se_L_plus_0_1cyc = cycle_average_1d(se_L_plus_0, se_df['t'], omega, 3, 6, 100)

s_L_plus_025_1cyc = cycle_average_1d(s_L_plus_025, s_df['t'], omega, 3, 6, 100)
s_L_plus_05_1cyc = cycle_average_1d(s_L_plus_05, s_df['t'], omega, 3, 6, 100)
s_L_plus_15_1cyc = cycle_average_1d(s_L_plus_15, s_df['t'], omega, 3, 6, 100)
s_L_plus_0_1cyc = cycle_average_1d(s_L_plus_0, s_df['t'], omega, 3, 6, 100)


se_sal_trans_coeff_025_1_1cyc = cycle_average_1d(se_sal_trans_coeff_025_1, se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_05_1_1cyc = cycle_average_1d(se_sal_trans_coeff_05_1, se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_15_1_1cyc = cycle_average_1d(se_sal_trans_coeff_15_1, se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_0_1cyc = cycle_average_1d(se_sal_trans_coeff_0, se_df['t'], omega, 3, 6, 100)


s_sal_trans_coeff_025_1_1cyc = cycle_average_1d(s_sal_trans_coeff_025_1, s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_05_1_1cyc = cycle_average_1d(s_sal_trans_coeff_05_1, s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_15_1_1cyc = cycle_average_1d(s_sal_trans_coeff_15_1, s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_0_1cyc = cycle_average_1d(s_sal_trans_coeff_0, s_df['t'], omega, 3, 6, 100)



se_heat_trans_coeff_025_1_1cyc = cycle_average_1d(se_heat_trans_coeff_025_1, se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_05_1_1cyc = cycle_average_1d(se_heat_trans_coeff_05_1, se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_15_1_1cyc = cycle_average_1d(se_heat_trans_coeff_15_1, se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_0_1cyc = cycle_average_1d(se_heat_trans_coeff_0, se_df['t'], omega, 3, 6, 100)


s_heat_trans_coeff_025_1_1cyc = cycle_average_1d(s_heat_trans_coeff_025_1, s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_05_1_1cyc = cycle_average_1d(s_heat_trans_coeff_05_1, s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_15_1_1cyc = cycle_average_1d(s_heat_trans_coeff_15_1, s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_0_1cyc = cycle_average_1d(s_heat_trans_coeff_0, s_df['t'], omega, 3, 6, 100)



se_u_star_3_025_1cyc = cycle_average_1d(se_u_star_3[:,0], se_df['t'], omega, 3, 6, 100)
se_u_star_3_05_1cyc = cycle_average_1d(se_u_star_3[:,1], se_df['t'], omega, 3, 6, 100)
se_u_star_3_15_1cyc = cycle_average_1d(se_u_star_3[:,2], se_df['t'], omega, 3, 6, 100)
se_ustar_1cyc = cycle_average_1d(se_ustar, se_df['t'], omega, 3, 6, 100)

s_u_star_3_025_1cyc = cycle_average_1d(s_u_star_3[:,0], s_df['t'], omega, 3, 6, 100)
s_u_star_3_05_1cyc = cycle_average_1d(s_u_star_3[:,1], s_df['t'], omega, 3, 6, 100)
s_u_star_3_15_1cyc = cycle_average_1d(s_u_star_3[:,2], s_df['t'], omega, 3, 6, 100)
s_ustar_1cyc = cycle_average_1d(s_ustar, s_df['t'], omega, 3, 6, 100)

# %%
se_sal_trans_coeff_025_2_1cyc = cycle_average_1d(se_sal_trans_coeff_025_2[:,0], se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_05_2_1cyc = cycle_average_1d(se_sal_trans_coeff_05_2[:,0], se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_15_2_1cyc = cycle_average_1d(se_sal_trans_coeff_15_2[:,0], se_df['t'], omega, 3, 6, 100)
se_sal_trans_coeff_0_2_1cyc = cycle_average_1d(se_sal_trans_coeff_0_2[:,0], se_df['t'], omega, 3, 6, 100)

s_sal_trans_coeff_025_2_1cyc = cycle_average_1d(s_sal_trans_coeff_025_2[:,0], s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_05_2_1cyc = cycle_average_1d(s_sal_trans_coeff_05_2[:,0], s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_15_2_1cyc = cycle_average_1d(s_sal_trans_coeff_15_2[:,0], s_df['t'], omega, 3, 6, 100)
s_sal_trans_coeff_0_2_1cyc = cycle_average_1d(s_sal_trans_coeff_0_2[:,0], s_df['t'], omega, 3, 6, 100)

se_heat_trans_coeff_025_2_1cyc = cycle_average_1d(se_heat_trans_coeff_025_2[:,0], se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_05_2_1cyc = cycle_average_1d(se_heat_trans_coeff_05_2[:,0], se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_15_2_1cyc = cycle_average_1d(se_heat_trans_coeff_15_2[:,0], se_df['t'], omega, 3, 6, 100)
se_heat_trans_coeff_0_2_1cyc = cycle_average_1d(se_heat_trans_coeff_0_2[:,0], se_df['t'], omega, 3, 6, 100)

s_heat_trans_coeff_025_2_1cyc = cycle_average_1d(s_heat_trans_coeff_025_2[:,0], s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_05_2_1cyc = cycle_average_1d(s_heat_trans_coeff_05_2[:,0], s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_15_2_1cyc = cycle_average_1d(s_heat_trans_coeff_15_2[:,0], s_df['t'], omega, 3, 6, 100)
s_heat_trans_coeff_0_2_1cyc = cycle_average_1d(s_heat_trans_coeff_0_2[:,0], s_df['t'], omega, 3, 6, 100)

# %%
se_time_1cyc = cycle_average_1d(se_heat_trans_coeff_0_2[:,0], se_df['t'], omega, 3, 6, 100)[0]
s_time_1cyc = cycle_average_1d(s_heat_trans_coeff_025_2[:,0], s_df['t'], omega, 3, 6, 100)[0]

# %%
fig, ((ax4),(ax1),(ax3)) = plt.subplots(nrows=3,ncols=1,figsize=(3,4))

ax1.plot(s_time_1cyc/T,s_L_plus_025_1cyc[1],linewidth=0.8,color='orangered',label='Stokes',linestyle='-')
#ax2.plot(s_time_1cyc/T,s_L_plus_05_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax3.plot(s_time_1cyc/T,s_L_plus_15_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax4.plot(s_time_1cyc/T,s_L_plus_0_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax1.plot(se_time_1cyc/T,se_L_plus_025_1cyc[1],linewidth=0.8,color='goldenrod',label='Stokes-Ekman',linestyle='-')
#ax2.plot(se_time_1cyc/T,se_L_plus_05_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax3.plot(se_time_1cyc/T,se_L_plus_15_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax4.plot(se_time_1cyc/T,se_L_plus_0_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')


#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
#ax2.set_xlim(0,1)
ax3.set_xlim(0,1)
ax4.set_xlim(0,1)

ax1.set_ylim(1,1e5)
#ax2.set_ylim(1,1e5)
ax3.set_ylim(1,1e5)
ax4.set_ylim(1,1e5)

#ax.yaxis.set_minor_locator(MultipleLocator(5000))
#ax.xaxis.set_minor_locator(MultipleLocator(0.2))


ax1.set_ylabel('0.25m',fontsize=9)
#ax2.set_ylabel('0.5m',fontsize=9)
ax3.set_ylabel('1.5m',fontsize=9)
ax4.set_ylabel('Wall Stress',fontsize=9)

ax1.set_yscale("log")
#ax2.set_yscale("log")
ax3.set_yscale("log")
ax4.set_yscale("log")


ax1.axhline(20000,linewidth=0.75,color='black')
#ax2.axhline(20000,linewidth=0.75,color='black')
ax3.axhline(20000,linewidth=0.75,color='black')
ax4.axhline(20000,linewidth=0.75,color='black')


fig.legend(ncol=1)

plt.suptitle(r'L$^{+}$',fontsize=9)

plt.tight_layout()
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,figsize=(4,3),sharex=True)


ax1.plot(s_time_1cyc/T,s_L_plus_0_1cyc[1],linewidth=0.8,color='slategray',label='Wallstress',linestyle='dotted')
ax2.plot(se_time_1cyc/T,se_L_plus_0_1cyc[1],linewidth=0.8,color='slategray',linestyle='dotted')

ax1.plot(s_time_1cyc/T,s_L_plus_025_1cyc[1],linewidth=0.8,color='slategray',label='0.25m',linestyle='--')
ax2.plot(se_time_1cyc/T,se_L_plus_025_1cyc[1],linewidth=0.8,color='slategray',linestyle='--')

ax1.plot(s_time_1cyc/T,s_L_plus_15_1cyc[1],linewidth=0.8,color='slategray',label='1.25m',linestyle='-')
ax2.plot(se_time_1cyc/T,se_L_plus_15_1cyc[1],linewidth=0.8,color='slategray',linestyle='-')


ax1.set_xlim(0,1)
ax2.set_xlim(0,1)

ax1.set_ylim(1,1e5)
ax2.set_ylim(1,1e5)

#ax.yaxis.set_minor_locator(MultipleLocator(5000))
#ax.xaxis.set_minor_locator(MultipleLocator(0.2))


ax1.set_ylabel('Stokes',fontsize=8)
ax2.set_ylabel('Stokes-Ekman',fontsize=8)

ax1.set_yscale("log")
ax2.set_yscale("log")


ax1.axhline(20000,linewidth=0.9,color='black')
ax2.axhline(20000,linewidth=0.9,color='black')

ax1.axhline(2000,linewidth=0.9,color='black')
ax2.axhline(2000,linewidth=0.9,color='black')

lgd = fig.legend(bbox_to_anchor=(0.129, 0.77, 0.8275, 0.3), ncol=3, mode="expand", borderaxespad=0.)

#plt.suptitle(r'L$^{+}$',fontsize=9)

ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax1.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])


plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(nrows=1,ncols=1,figsize=(4,1.5))


ax1.axhline(20000,linewidth=0.9,color='black')
ax1.axhline(2000,linewidth=0.9,color='black')

ax1.plot(s_time_1cyc/T,s_L_plus_0_1cyc[1],linewidth=0.8,color='indianred',linestyle='-',label='Non-Rotating')
ax1.plot(se_time_1cyc/T,se_L_plus_0_1cyc[1],linewidth=0.8,color='royalblue',linestyle='-',label='Rotating')




ax1.set_xlim(0,1)
#ax2.set_xlim(0,1)

ax1.set_ylim(1,1e5)
#ax2.set_ylim(1,1e5)

#ax.yaxis.set_minor_locator(MultipleLocator(5000))
#ax.xaxis.set_minor_locator(MultipleLocator(0.2))


ax1.set_ylabel(r'L$^{+}$',fontsize=8)
#ax2.set_ylabel('Stokes-Ekman',fontsize=8)

ax1.set_yscale("log")
#ax2.set_yscale("log")


#ax2.axhline(20000,linewidth=0.9,color='black')


#lgd = fig.legend(bbox_to_anchor=(0.129, 0.8125, 0.835, 0.3), ncol=2, mode="expand", borderaxespad=0.)

#plt.suptitle(r'L$^{+}$',fontsize=9)

ax1.set_xticks([0,0.25,0.5,0.75,1])
#ax2.set_xticks([0,0.25,0.5,0.75,1])

#ax1.set_xticklabels([])
ax1.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])
ax1.xaxis.set_minor_locator(MultipleLocator(0.05))

ax1.set_yticks([1,1e1,1e2,1e3,1e4,1e5])
#ax1.set_yticklabels(['1','','1e2','','1e4',''])

plt.legend()


plt.tight_layout()
plt.show()

# %%
# %store -r s_ustar
# %store -r se_ustar

# %store -r meltrate_s
# %store -r meltrate_se

# %%
s_ustar_1cyc = cycle_average_1d(s_ustar, s_df['t'], omega, 3, 6, 100)
se_ustar_1cyc = cycle_average_1d(se_ustar, se_df['t'], omega, 3, 6, 100)

meltrate_s_1cyc = cycle_average_1d(meltrate_s, s_df['t'], omega, 3, 6, 100)
meltrate_se_1cyc = cycle_average_1d(meltrate_se, se_df['t'], omega, 3, 6, 100)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3,ncols=1,figsize=(4,4),sharex=True)


ax1.axhline(20000,linewidth=0.9,color='black')
ax1.axhline(2000,linewidth=0.9,color='black')

ax1.plot(s_time_1cyc/T,s_L_plus_0_1cyc[1],linewidth=0.8,color='indianred',linestyle='-',label='Non-Rotating')
ax1.plot(se_time_1cyc/T,se_L_plus_0_1cyc[1],linewidth=0.8,color='royalblue',linestyle='-',label='Rotating')


ax1.set_xlim(0,1)
ax1.set_ylim(1,1e5)

ax1.set_ylabel(r'L$^{+}$',fontsize=8)
ax1.set_yscale("log")

ax1.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])
ax1.xaxis.set_minor_locator(MultipleLocator(0.05))

ax1.set_yticks([1,1e1,1e2,1e3,1e4,1e5])

ax1.legend()



ax2.plot(s_time_1cyc/T,meltrate_s_1cyc[1],linewidth=0.8,color='indianred',linestyle='-',label='Non-Rotating')
ax2.plot(se_time_1cyc/T,meltrate_se_1cyc[1],linewidth=0.8,color='royalblue',linestyle='-',label='Rotating')


ax2.set_xlim(0,1)
ax2.set_ylim(0,0.006)

ax2.set_ylabel(r'Melt Rate',fontsize=8)

ax2.set_xticks([0,0.25,0.5,0.75,1])

ax2.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])
ax2.xaxis.set_minor_locator(MultipleLocator(0.05))
ax2.yaxis.set_minor_locator(MultipleLocator(0.0005))



ax3.plot(s_time_1cyc/T,s_ustar_1cyc[1],linewidth=0.8,color='indianred',linestyle='-',label='Non-Rotating')
ax3.plot(se_time_1cyc/T,se_ustar_1cyc[1],linewidth=0.8,color='royalblue',linestyle='-',label='Rotating')


ax3.set_xlim(0,1)
ax3.set_ylim(0,0.00125)

ax3.set_ylabel(r'u*',fontsize=8)

ax3.set_xticks([0,0.25,0.5,0.75,1])

ax3.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])
ax3.xaxis.set_minor_locator(MultipleLocator(0.05))
ax3.yaxis.set_minor_locator(MultipleLocator(0.00005))




plt.tight_layout()
plt.show()

# %%
np.log(20000)
# Out:
# 9.903487552536127

# %%
fig, ((ax4),(ax1),(ax2),(ax3)) = plt.subplots(nrows=4,ncols=1,figsize=(3,5),sharex=True)

ax1.plot(s_time_1cyc/T,s_u_star_3_025_1cyc[1],linewidth=0.8,color='orangered',label='Stokes',linestyle='-')
ax2.plot(s_time_1cyc/T,s_u_star_3_05_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax3.plot(s_time_1cyc/T,s_u_star_3_15_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax4.plot(s_time_1cyc/T,s_ustar_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax1.plot(se_time_1cyc/T,se_u_star_3_025_1cyc[1],linewidth=0.8,color='goldenrod',label='Stokes-Ekman',linestyle='-')
ax2.plot(se_time_1cyc/T,se_u_star_3_05_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax3.plot(se_time_1cyc/T,se_u_star_3_15_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax4.plot(se_time_1cyc/T,se_ustar_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')

#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)
ax3.set_xlim(0,1)
ax4.set_xlim(0,1)

ax1.set_ylim(0,0.0015)
ax2.set_ylim(0,0.0015)
ax3.set_ylim(0,0.0015)
ax4.set_ylim(0,0.0015)

ax1.set_ylabel('0.25m',fontsize=9)
ax2.set_ylabel('0.5m',fontsize=9)
ax3.set_ylabel('1.5m',fontsize=9)
ax4.set_ylabel('Wall Stress',fontsize=9)

ax4.set_title(r'u$^{*}$',fontsize=9)

fig.legend(ncol=1)


plt.tight_layout()
plt.show()

# %%
s_heat_trans_coeff_025_1.shape
# Out:
# (450,)

# %%
fig, ((ax4,ax41),(ax1,ax11),(ax2,ax21),(ax3,ax31)) = plt.subplots(nrows=4,ncols=2,figsize=(6,4.5),sharex=True)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='orangered',label='Stokes',linestyle='-')
ax2.plot(s_time_1cyc/T,s_heat_trans_coeff_05_1_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax3.plot(s_time_1cyc/T,s_heat_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax4.plot(s_time_1cyc/T,s_heat_trans_coeff_0_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax1.plot(se_time_1cyc/T,se_heat_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='goldenrod',label='Stokes-Ekman',linestyle='-')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_05_1_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax3.plot(se_time_1cyc/T,se_heat_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax4.plot(se_time_1cyc/T,se_heat_trans_coeff_0_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)
ax3.set_xlim(0,1)
ax4.set_xlim(0,1)




ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax21.plot(s_time_1cyc/T,-s_heat_trans_coeff_05_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax31.plot(s_time_1cyc/T,-s_heat_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax41.plot(s_time_1cyc/T,-s_heat_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax11.plot(se_time_1cyc/T,-se_heat_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_05_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax31.plot(se_time_1cyc/T,-se_heat_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax41.plot(se_time_1cyc/T,-se_heat_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)
ax31.set_xlim(0,1)
ax41.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{T}$',fontsize=9)
ax4.set_title('Formula 1')
ax41.set_title('Formula 2')


ax1.set_ylim(0.010,0.015)
ax2.set_ylim(0.010,0.015)
ax3.set_ylim(0.010,0.015)
ax4.set_ylim(0.010,0.015)

ax11.set_ylim(0.010,0.015)
ax21.set_ylim(0.010,0.015)
ax31.set_ylim(0.010,0.015)
ax41.set_ylim(0.010,0.015)


ax1.set_ylabel('0.25m',fontsize=9)
ax2.set_ylabel('0.5m',fontsize=9)
ax3.set_ylabel('1.5m',fontsize=9)
ax4.set_ylabel('Wall Stress',fontsize=9)


fig.legend(ncol=2)


plt.tight_layout()
plt.show()

# %%
fig, ((ax4,ax41),(ax1,ax11),(ax2,ax21),(ax3,ax31)) = plt.subplots(nrows=4,ncols=2,figsize=(6,4.5),sharex=True)

ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='orangered',label='Stokes',linestyle='-')
ax2.plot(s_time_1cyc/T,s_sal_trans_coeff_05_1_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax3.plot(s_time_1cyc/T,s_sal_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax4.plot(s_time_1cyc/T,s_sal_trans_coeff_0_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax1.plot(se_time_1cyc/T,se_sal_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='goldenrod',label='Stokes-Ekman',linestyle='-')
ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_05_1_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax3.plot(se_time_1cyc/T,se_sal_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax4.plot(se_time_1cyc/T,se_sal_trans_coeff_0_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)
ax3.set_xlim(0,1)
ax4.set_xlim(0,1)




ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax21.plot(s_time_1cyc/T,-s_sal_trans_coeff_05_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax31.plot(s_time_1cyc/T,-s_sal_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax41.plot(s_time_1cyc/T,-s_sal_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax11.plot(se_time_1cyc/T,-se_sal_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_05_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax31.plot(se_time_1cyc/T,-se_sal_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax41.plot(se_time_1cyc/T,-se_sal_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)
ax31.set_xlim(0,1)
ax41.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{S}$',fontsize=9)
ax4.set_title('Formula 1')
ax41.set_title('Formula 2')


ax1.set_ylim(0.000605,0.000609)
ax2.set_ylim(0.000605,0.000609)
ax3.set_ylim(0.000605,0.000609)
ax4.set_ylim(0.000605,0.000609)

ax11.set_ylim(0,0.005)
ax21.set_ylim(0,0.005)
ax31.set_ylim(0,0.005)
ax41.set_ylim(0,0.005)


ax1.set_ylabel('0.25m',fontsize=9)
ax2.set_ylabel('0.5m',fontsize=9)
ax3.set_ylabel('1.5m',fontsize=9)
ax4.set_ylabel('Wall Stress',fontsize=9)


fig.legend(ncol=2)


plt.tight_layout()
plt.show()

# %%
fig, ((ax1,ax11),(ax2,ax21),(ax3,ax31)) = plt.subplots(nrows=3,ncols=2,figsize=(6,3.5),sharex=True)

ax2.plot(s_time_1cyc/T,s_heat_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='orangered',label='Stokes',linestyle='-')
ax3.plot(s_time_1cyc/T,s_heat_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_0_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_025_1_1cyc[1],linewidth=0.8,color='goldenrod',label='Stokes-Ekman',linestyle='-')
ax3.plot(se_time_1cyc/T,se_heat_trans_coeff_15_1_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax1.plot(se_time_1cyc/T,se_heat_trans_coeff_0_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)
ax3.set_xlim(0,1)




ax21.plot(s_time_1cyc/T,-s_heat_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax31.plot(s_time_1cyc/T,-s_heat_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')
ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='orangered',linestyle='-')

ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_025_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax31.plot(se_time_1cyc/T,-se_heat_trans_coeff_15_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')
ax11.plot(se_time_1cyc/T,-se_heat_trans_coeff_0_2_1cyc[1],linewidth=0.8,color='goldenrod',linestyle='-')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)
ax31.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{T}$',fontsize=9)
ax1.set_title('Formula 1')
ax11.set_title('Formula 2')


ax1.set_ylim(0.010,0.015)
ax2.set_ylim(0.010,0.015)
ax3.set_ylim(0.010,0.015)

ax11.set_ylim(0.010,0.015)
ax21.set_ylim(0.010,0.015)
ax31.set_ylim(0.010,0.015)


ax2.set_ylabel('0.25m',fontsize=9)
ax3.set_ylabel('1.25m',fontsize=9)
ax1.set_ylabel('Wall Stress',fontsize=9)


fig.legend(ncol=2)


plt.tight_layout()
plt.show()

# %%
s_gammat_025_20k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammat_025_20k_1[i] = s_heat_trans_coeff_025_1_1cyc[1][i]

        
s_gammat_0_20k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammat_0_20k_1[i] = s_heat_trans_coeff_0_1cyc[1][i]

# %%
s_gammat_025_20k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammat_025_20k_2[i] = s_heat_trans_coeff_025_2_1cyc[1][i]

        
s_gammat_0_20k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammat_0_20k_2[i] = s_heat_trans_coeff_0_2_1cyc[1][i]

# %%
s_gammat_025_2k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 2000):
        s_gammat_025_2k_1[i] = s_heat_trans_coeff_025_1_1cyc[1][i]

        
s_gammat_0_2k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 2000):
        s_gammat_0_2k_1[i] = s_heat_trans_coeff_0_1cyc[1][i]

# %%
s_gammat_025_2k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 2000):
        s_gammat_025_2k_2[i] = s_heat_trans_coeff_025_2_1cyc[1][i]

        
s_gammat_0_2k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 2000):
        s_gammat_0_2k_2[i] = s_heat_trans_coeff_0_2_1cyc[1][i]

# %%
s_gammas_025_20k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammas_025_20k_1[i] = s_sal_trans_coeff_025_1_1cyc[1][i]

        
s_gammas_0_20k_1 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammas_0_20k_1[i] = s_sal_trans_coeff_0_1cyc[1][i]

# %%
s_gammas_025_20k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammas_025_20k_2[i] = s_sal_trans_coeff_025_2_1cyc[1][i]

        
s_gammas_0_20k_2 = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        s_gammas_0_20k_2[i] = s_sal_trans_coeff_0_2_1cyc[1][i]

# %%
fig, ((ax11,ax1),(ax21,ax2)) = plt.subplots(nrows=2,ncols=2,figsize=(6,2.5),sharex=True)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_0_1cyc[1], linewidth=1,color='slategray',label='Wallstress',linestyle='-')
ax1.plot(s_time_1cyc/T,s_gammat_0_20k_1, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax1.plot(s_time_1cyc/T,s_gammat_0_2k_1, linewidth=4,color='skyblue',linestyle='-',alpha=0.3)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_025_1_1cyc[1], linewidth=1,color='slategray',label='0.25m',linestyle='--')
ax1.plot(s_time_1cyc/T,s_gammat_025_20k_1, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax1.plot(s_time_1cyc/T,s_gammat_025_2k_1, linewidth=4,color='skyblue',linestyle='-',alpha=0.3)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_15_1_1cyc[1], linewidth=1,color='slategray',label='1.25m',linestyle='dotted')

ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_0_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_025_1_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_15_1_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)



ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax11.plot(s_time_1cyc/T,-s_gammat_0_20k_2, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax11.plot(s_time_1cyc/T,-s_gammat_0_2k_2, linewidth=4,color='skyblue',linestyle='-',alpha=0.3)

ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax11.plot(s_time_1cyc/T,-s_gammat_025_20k_2, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax11.plot(s_time_1cyc/T,-s_gammat_025_2k_2, linewidth=4,color='skyblue',linestyle='-',alpha=0.3)

ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')

ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{T}$',fontsize=9)
ax1.set_title('Formula 1',fontsize=8)
ax11.set_title('Formula 2',fontsize=8)


ax1.set_ylim(0.,0.025)
ax2.set_ylim(0.,0.025)

ax11.set_ylim(0,0.025)
ax21.set_ylim(0,0.025)


ax11.set_ylabel('Stokes',fontsize=8)
ax21.set_ylabel('Stokes-Ekman',fontsize=8)


lgd = fig.legend(bbox_to_anchor=(0.125, 0.69, 0.84, 0.3), ncol=3, borderaxespad=0.)


ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax2.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])

ax11.set_xticks([0,0.25,0.5,0.75,1])
ax21.set_xticks([0,0.25,0.5,0.75,1])

ax11.set_xticklabels([])
ax21.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])


ax11.axhline(0.011,linewidth=1,color='black')
ax21.axhline(0.011,linewidth=1,color='black')

ax1.axhline(0.011,linewidth=1,color='black')
ax2.axhline(0.011,linewidth=1,color='black')


plt.tight_layout()
plt.show()

# %%
fig, ((ax1,ax11),(ax2,ax21)) = plt.subplots(nrows=2,ncols=2,figsize=(6,2.5),sharex=True)

ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_0_1cyc[1], linewidth=1,color='slategray',label='Wallstress',linestyle='dotted')
ax1.plot(s_time_1cyc/T,s_gammas_0_20k_1, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_025_1_1cyc[1], linewidth=1,color='slategray',label='0.25m',linestyle='--')
ax1.plot(s_time_1cyc/T,s_gammas_025_20k_1, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_15_1_1cyc[1], linewidth=1,color='slategray',label='1.25m',linestyle='-')

ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_0_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')
ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_025_1_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_15_1_1cyc[1],linewidth=1,color='slategray',linestyle='-')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)



ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')
ax11.plot(s_time_1cyc/T,-s_gammas_0_20k_2, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax11.plot(s_time_1cyc/T,-s_gammas_025_20k_2, linewidth=4,color='dimgray',linestyle='-',alpha=0.4)
ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')

ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')
ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{S}$',fontsize=9)
ax1.set_title('Formula 1',fontsize=8)
ax11.set_title('Formula 2',fontsize=8)


ax1.set_ylim(0.000605,0.000609)
ax2.set_ylim(0.000605,0.000609)

ax11.set_ylim(0,0.005)
ax21.set_ylim(0,0.005)


ax1.set_ylabel('Stokes',fontsize=8)
ax2.set_ylabel('Stokes-Ekman',fontsize=8)


lgd = fig.legend(bbox_to_anchor=(0.125, 0.69, 0.84, 0.3), ncol=3, borderaxespad=0.)


ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax2.set_xticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])

ax11.set_xticks([0,0.25,0.5,0.75,1])
ax21.set_xticks([0,0.25,0.5,0.75,1])

ax11.set_xticklabels([])
ax21.set_xticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])



plt.tight_layout()
plt.show()

# %%
s_L_plus_0_1cyc[0]
# Out:
# array([    0.        ,   100.36395929,   200.72791857,   301.09187786,
#          401.45583715,   501.81979643,   602.18375572,   702.54771501,
#          802.91167429,   903.27563358,  1003.63959287,  1104.00355215,
#         1204.36751144,  1304.73147073,  1405.09543001,  1505.4593893 ,
#         1605.82334859,  1706.18730787,  1806.55126716,  1906.91522645,
#         2007.27918573,  2107.64314502,  2208.00710431,  2308.37106359,
#         2408.73502288,  2509.09898217,  2609.46294145,  2709.82690074,
#         2810.19086003,  2910.55481931,  3010.9187786 ,  3111.28273789,
#         3211.64669717,  3312.01065646,  3412.37461575,  3512.73857503,
#         3613.10253432,  3713.4664936 ,  3813.83045289,  3914.19441218,
#         4014.55837146,  4114.92233075,  4215.28629004,  4315.65024932,
#         4416.01420861,  4516.3781679 ,  4616.74212718,  4717.10608647,
#         4817.47004576,  4917.83400504,  5018.19796433,  5118.56192362,
# ...

# %%
L_plus_cri_20k = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 20000):
        L_plus_cri_20k[i] = s_L_plus_0_1cyc[0][i]
        
        
L_plus_cri_2k = np.nan*np.zeros(445)

for i in range(0,445,1):
    if (s_L_plus_0_1cyc[1][i] > 2000):
        L_plus_cri_2k[i] = s_L_plus_0_1cyc[0][i]

# %%
np.array([[3914.19441218,14753.50201513],[25994.26545523,37134.66493605]])/T
# Out:
# array([[0.08783784, 0.33108108],
#        [0.58333333, 0.83333333]])

# %%
np.array([[100.36395929,18366.60454945],[22280.79896163,40747.76747037]])/T
# Out:
# array([[0.00225225, 0.41216216],
#        [0.5       , 0.91441441]])

# %%
fig, ((ax11,ax1),(ax21,ax2)) = plt.subplots(nrows=2,ncols=2,figsize=(6,2.5),sharex=True,sharey=True)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_0_1cyc[1], linewidth=1,color='slategray',label='Wallstress',linestyle='-')
ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_025_1_1cyc[1], linewidth=1,color='slategray',label='0.25m',linestyle='--')
ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_15_1_1cyc[1], linewidth=1,color='slategray',label='1.25m',linestyle='dotted')

ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_0_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_025_1_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_15_1_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)



ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')

ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{T}$',fontsize=9)
ax1.set_title('Formula 1',fontsize=8)
ax11.set_title('Formula 2',fontsize=8)


ax1.set_ylim(0.,0.025)
ax2.set_ylim(0.,0.025)

ax11.set_ylim(0,0.025)
ax21.set_ylim(0,0.025)


ax11.set_ylabel('Non-Rotating',fontsize=8)
ax21.set_ylabel('Rotat',fontsize=8)


lgd = fig.legend(bbox_to_anchor=(0.125, 0.69, 0.84, 0.3), ncol=3, borderaxespad=0.)


ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax2.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])

ax11.set_xticks([0,0.25,0.5,0.75,1])
ax21.set_xticks([0,0.25,0.5,0.75,1])

ax11.set_xticklabels([])
ax21.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])


ax11.axhline(0.011,linewidth=1,color='black')
ax21.axhline(0.011,linewidth=1,color='black')

ax1.axhline(0.011,linewidth=1,color='black')
ax2.axhline(0.011,linewidth=1,color='black')


ax11.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax11.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax11.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax11.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')


ax1.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax1.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax1.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax1.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')



ax1.xaxis.set_minor_locator(MultipleLocator(0.05))
ax11.xaxis.set_minor_locator(MultipleLocator(0.05))
ax2.xaxis.set_minor_locator(MultipleLocator(0.05))
ax21.xaxis.set_minor_locator(MultipleLocator(0.05))

ax1.yaxis.set_minor_locator(MultipleLocator(0.002))
ax11.yaxis.set_minor_locator(MultipleLocator(0.002))
ax2.yaxis.set_minor_locator(MultipleLocator(0.002))
ax21.yaxis.set_minor_locator(MultipleLocator(0.002))



plt.tight_layout()
plt.show()

# %%
fig, ((ax11,ax1),(ax21,ax2)) = plt.subplots(nrows=2,ncols=2,figsize=(6,2.5),sharex=True,sharey=True)

ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_0_1cyc[1], linewidth=1,color='slategray',label='Wallstress',linestyle='-')
ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_025_1_1cyc[1], linewidth=1,color='slategray',label='0.25m',linestyle='--')
ax1.plot(s_time_1cyc/T,s_sal_trans_coeff_15_1_1cyc[1], linewidth=1,color='slategray',label='1.25m',linestyle='dotted')

ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_0_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_025_1_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax2.plot(se_time_1cyc/T,se_sal_trans_coeff_15_1_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)



ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax11.plot(s_time_1cyc/T,-s_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')

ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax21.plot(se_time_1cyc/T,-se_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{S}$',fontsize=9)
ax1.set_title('Formula 1',fontsize=8)
ax11.set_title('Formula 2',fontsize=8)


ax1.set_ylim(0,0.001)
ax2.set_ylim(0,0.001)

ax11.set_ylim(0,0.001)
ax21.set_ylim(0,0.001)


ax11.set_ylabel('Non-Rotating',fontsize=8)
ax21.set_ylabel('Rotating',fontsize=8)


lgd = fig.legend(bbox_to_anchor=(0.125, 0.69, 0.84, 0.3), ncol=3, borderaxespad=0.)


ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax2.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])

ax11.set_xticks([0,0.25,0.5,0.75,1])
ax21.set_xticks([0,0.25,0.5,0.75,1])

ax11.set_xticklabels([])
ax21.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])



ax11.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax11.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax11.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax11.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')


ax1.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax1.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax1.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax1.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')



ax1.xaxis.set_minor_locator(MultipleLocator(0.05))
ax11.xaxis.set_minor_locator(MultipleLocator(0.05))
ax2.xaxis.set_minor_locator(MultipleLocator(0.05))
ax21.xaxis.set_minor_locator(MultipleLocator(0.05))

ax1.yaxis.set_minor_locator(MultipleLocator(0.0001))
ax11.yaxis.set_minor_locator(MultipleLocator(0.0001))
ax2.yaxis.set_minor_locator(MultipleLocator(0.0001))
ax21.yaxis.set_minor_locator(MultipleLocator(0.0001))






plt.tight_layout()
plt.show()

# %%
fig, ((ax11,ax1),(ax21,ax2)) = plt.subplots(nrows=2,ncols=2,figsize=(6,2.5),sharex=True,sharey=True)

ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_0_1cyc[1]/s_sal_trans_coeff_0_1cyc[1], linewidth=1,color='slategray',label='Wallstress',linestyle='-')
ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_025_1_1cyc[1]/s_sal_trans_coeff_025_1_1cyc[1], linewidth=1,color='slategray',label='0.25m',linestyle='--')
ax1.plot(s_time_1cyc/T,s_heat_trans_coeff_15_1_1cyc[1]/s_sal_trans_coeff_15_1_1cyc[1], linewidth=1,color='slategray',label='1.25m',linestyle='dotted')

ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_0_1cyc[1]/se_sal_trans_coeff_0_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_025_1_1cyc[1]/se_sal_trans_coeff_025_1_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax2.plot(se_time_1cyc/T,se_heat_trans_coeff_15_1_1cyc[1]/se_sal_trans_coeff_15_1_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')



#ax.set_ylim(0,70000)
ax1.set_xlim(0,1)
ax2.set_xlim(0,1)



ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_0_2_1cyc[1]/-s_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_025_2_1cyc[1]/-s_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax11.plot(s_time_1cyc/T,-s_heat_trans_coeff_15_2_1cyc[1]/-s_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')

ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_0_2_1cyc[1]/-se_sal_trans_coeff_0_2_1cyc[1],linewidth=1,color='slategray',linestyle='-')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_025_2_1cyc[1]/-se_sal_trans_coeff_025_2_1cyc[1],linewidth=1,color='slategray',linestyle='--')
ax21.plot(se_time_1cyc/T,-se_heat_trans_coeff_15_2_1cyc[1]/-se_sal_trans_coeff_15_2_1cyc[1],linewidth=1,color='slategray',linestyle='dotted')


#ax.set_ylim(0,70000)
ax11.set_xlim(0,1)
ax21.set_xlim(0,1)



plt.suptitle(r'$\Gamma_{T}/\Gamma_{S}$',fontsize=9)
ax1.set_title('Formula 1',fontsize=8)
ax11.set_title('Formula 2',fontsize=8)


#ax1.set_ylim(0.,0.025)
#ax2.set_ylim(0.,0.025)

#ax11.set_ylim(0,0.025)
#ax21.set_ylim(0,0.025)

#
ax11.set_ylabel('Non-Rotating',fontsize=8)
ax21.set_ylabel('Rotating',fontsize=8)


lgd = fig.legend(bbox_to_anchor=(0.125, 0.69, 0.84, 0.3), ncol=3, borderaxespad=0.)


ax1.set_xticks([0,0.25,0.5,0.75,1])
ax2.set_xticks([0,0.25,0.5,0.75,1])

ax1.set_xticklabels([])
ax2.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])

ax11.set_xticks([0,0.25,0.5,0.75,1])
ax21.set_xticks([0,0.25,0.5,0.75,1])

ax11.set_xticklabels([])
ax21.set_xticklabels(['0','$\pi$/2','$\pi$','3$\pi$/2','$2\pi$'])


ax11.axhline(0.011,linewidth=1,color='black')
ax21.axhline(0.011,linewidth=1,color='black')

ax1.axhline(0.011,linewidth=1,color='black')
ax2.axhline(0.011,linewidth=1,color='black')


ax11.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax11.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax11.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax11.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')


ax1.axvspan(0.08783784, 0.33108108, alpha=0.15, color='dimgray')
ax1.axvspan(0.00225225, 0.41216216, alpha=0.15, color='skyblue')
ax1.axvspan(0.58333333, 0.83333333, alpha=0.15, color='dimgray')
ax1.axvspan(0.5       , 0.91441441, alpha=0.15, color='skyblue')



ax1.xaxis.set_minor_locator(MultipleLocator(0.05))
ax11.xaxis.set_minor_locator(MultipleLocator(0.05))
ax2.xaxis.set_minor_locator(MultipleLocator(0.05))
ax21.xaxis.set_minor_locator(MultipleLocator(0.05))

#ax1.yaxis.set_minor_locator(MultipleLocator(0.002))
#ax11.yaxis.set_minor_locator(MultipleLocator(0.002))
#ax2.yaxis.set_minor_locator(MultipleLocator(0.002))
#ax21.yaxis.set_minor_locator(MultipleLocator(0.002))



plt.tight_layout()
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,figsize=(2,3),sharex=True,sharey=True)

CS1 = ax1.scatter(-s_heat_trans_coeff_0_2_1cyc[1][:223],s_L_plus_0_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=0.5)
plt.colorbar(CS1, ax=ax1)


CS2 = ax2.scatter(-se_heat_trans_coeff_0_2_1cyc[1][:223],se_L_plus_0_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=0.5)
plt.colorbar(CS2, ax=ax2)

ax1.set_ylim(0,45000)

ax1.yaxis.set_minor_locator(MultipleLocator(2000))


plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(4,1.5))

ax1.plot(s_L_plus_0_1cyc[1][:223],s_heat_trans_coeff_0_1cyc[1][:223],linewidth=0.7,color='black',zorder=1,linestyle='dotted',label='Non-Rotating')
CS1 = ax1.scatter(s_L_plus_0_1cyc[1][:223],-s_heat_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=1.5,marker='o',alpha=0.5)

ax1.plot(se_L_plus_0_1cyc[1][:223],se_heat_trans_coeff_0_1cyc[1][:223],linewidth=1,color='black',zorder=2,alpha=1,linestyle='-',label='Rotating')
CS2 = ax1.scatter(se_L_plus_0_1cyc[1][:223],-se_heat_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='twilight_shifted',s=1.5,marker='o',alpha=0.5)


ax1.set_xlim(0,44000)
ax1.set_ylim(0,0.06)

cbar1 = plt.colorbar(CS1,label='Non-Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar1.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])
cbar2 = plt.colorbar(CS2,label='Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar2.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])


ax1.yaxis.set_minor_locator(MultipleLocator(0.005))
ax1.xaxis.set_minor_locator(MultipleLocator(2000))

ax1.set_ylabel(r'$\Gamma_{T}$',fontsize=7)
ax1.set_xlabel(r'L$^{+}$',fontsize=7)

ax1.axvline(2000,linewidth=0.75,color='dimgray')
ax1.axvline(20000,linewidth=0.75,color='dimgray')

ax1.axhline(0.012,linewidth=0.75,color='dimgray')

lgd = fig.legend(bbox_to_anchor=(0.13, 0.78, 0.495, 0.3), ncol=2, borderaxespad=0.)


plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(4,1.5))

ax1.plot(s_L_plus_0_1cyc[1][:223],s_sal_trans_coeff_0_1cyc[1][:223],linewidth=0.7,color='black',zorder=1,linestyle='dotted',label='Non-Rotating')
CS1 = ax1.scatter(s_L_plus_0_1cyc[1][:223],-s_sal_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=1.5,marker='o',alpha=0.5)

ax1.plot(se_L_plus_0_1cyc[1][:223],se_sal_trans_coeff_0_1cyc[1][:223],linewidth=1,color='black',zorder=2,alpha=1,linestyle='-',label='Rotating')
CS2 = ax1.scatter(se_L_plus_0_1cyc[1][:223],-se_sal_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='twilight_shifted',s=1.5,marker='o',alpha=0.5)


ax1.set_xlim(0,44000)
ax1.set_ylim(0,0.003)

cbar1 = plt.colorbar(CS1,label='Non-Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar1.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])
cbar2 = plt.colorbar(CS2,label='Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar2.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])


ax1.yaxis.set_minor_locator(MultipleLocator(0.00025))
ax1.xaxis.set_minor_locator(MultipleLocator(2000))

ax1.set_ylabel(r'$\Gamma_{S}$',fontsize=7)
ax1.set_xlabel(r'L$^{+}$',fontsize=7)

ax1.axvline(2000,linewidth=0.75,color='dimgray')
ax1.axvline(20000,linewidth=0.75,color='dimgray')

lgd = fig.legend(bbox_to_anchor=(0.13, 0.78, 0.5, 0.3), ncol=2, borderaxespad=0.)

ax1.axhline(3.9e-3,linewidth=0.75,color='dimgray')


plt.tight_layout()
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,figsize=(4,3),sharex=True,sharey=True)

CS1 = ax1.scatter(s_L_plus_0_1cyc[1][:223],s_heat_trans_coeff_0_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=0.5)
plt.colorbar(CS1, ax=ax1)


CS2 = ax2.scatter(se_L_plus_0_1cyc[1][:223],se_heat_trans_coeff_0_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=0.5)
plt.colorbar(CS2, ax=ax2)

ax1.set_xlim(0,45000)
ax1.set_ylim(0,0.06)

ax1.xaxis.set_minor_locator(MultipleLocator(1000))



plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(4,1.5))

ax1.plot(s_L_plus_0_1cyc[1][:223],s_heat_trans_coeff_0_1cyc[1][:223]/s_sal_trans_coeff_0_1cyc[1][:223],linewidth=0.7,color='black',zorder=1,linestyle='dotted',label='Non-Rotating')
CS1 = ax1.scatter(s_L_plus_0_1cyc[1][:223],s_heat_trans_coeff_0_2_1cyc[1][:223]/s_sal_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='cmo.phase',s=1.5,marker='o',alpha=0.5)

ax1.plot(se_L_plus_0_1cyc[1][:223],se_heat_trans_coeff_0_1cyc[1][:223]/se_sal_trans_coeff_0_1cyc[1][:223],linewidth=1,color='black',zorder=2,alpha=1,linestyle='-',label='Rotating')
CS2 = ax1.scatter(se_L_plus_0_1cyc[1][:223],se_heat_trans_coeff_0_2_1cyc[1][:223]/se_sal_trans_coeff_0_2_1cyc[1][:223],c=s_L_plus_0_1cyc[0][:223]/T,cmap='twilight_shifted',s=1.5,marker='o',alpha=0.5)


ax1.set_xlim(0,44000)
ax1.set_ylim(17,35)

cbar1 = plt.colorbar(CS1,label='Non-Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar1.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])
cbar2 = plt.colorbar(CS2,label='Rotating',ticks=[0,0.125,0.25,0.375,0.5])
cbar2.ax.set_yticklabels(['0','$\pi$/4','$\pi$/2','3$\pi$/4','$\pi$'])


ax1.yaxis.set_minor_locator(MultipleLocator(1))
ax1.xaxis.set_minor_locator(MultipleLocator(2000))

ax1.set_ylabel(r'$\Gamma_{T}/\Gamma_{S}$',fontsize=7)
ax1.set_xlabel(r'L$^{+}$',fontsize=7)

ax1.axvline(2000,linewidth=0.75,color='dimgray')
ax1.axvline(20000,linewidth=0.75,color='dimgray')

#ax1.axhline(0.011,linewidth=0.75,color='dimgray')

lgd = fig.legend(bbox_to_anchor=(0.13, 0.78, 0.475, 0.3), ncol=2, borderaxespad=0.)


plt.tight_layout()
plt.show()
